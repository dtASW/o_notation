# %% [markdown]
# # Data Exploration

# %% [markdown]
# Hey! During this first step, please, take a look at the data set and just explore it, find the types of each column and try to find interesting things. Don't worry about data cleaning. Just exploration for now.
# You can answer the following questions:
# - How many columns there are
# - The type of each column
# - The different values that a column can take
# - Which do you think are the most important columns? If we are looking at the overall score.
#
# Go wild! (Remember, so far, only exploration).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('Saber_11__2019-2.csv')
df.head()
# Out:
# C:\Users\dtoloza\AppData\Local\Temp\ipykernel_18504\1341599079.py:1: DtypeWarning: Columns (76,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Saber_11__2019-2.csv')
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M  02/18/2002 12:00:00 AM
# 1                 TI          COLOMBIA           M  06/28/2003 12:00:00 AM
# 2                 TI          COLOMBIA           M  06/02/2001 12:00:00 AM
# 3                 TI          COLOMBIA           M  04/26/2002 12:00:00 AM
# 4                 TI          COLOMBIA           M  02/05/2002 12:00:00 AM
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_TIENEETNIA ESTU_PAIS_RESIDE  \
# 0    20194  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1    20194  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# ...

# %%
df.shape
# Out:
# (546212, 82)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546212 entries, 0 to 546211
# Data columns (total 82 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ESTU_TIPODOCUMENTO             546212 non-null  object
#  1   ESTU_NACIONALIDAD              546212 non-null  object
#  2   ESTU_GENERO                    546212 non-null  object
#  3   ESTU_FECHANACIMIENTO           546212 non-null  object
#  4   PERIODO                        546212 non-null  int64
#  5   ESTU_CONSECUTIVO               546212 non-null  object
#  6   ESTU_ESTUDIANTE                546212 non-null  object
#  7   ESTU_TIENEETNIA                546212 non-null  object
#  8   ESTU_PAIS_RESIDE               546212 non-null  object
#  9   ESTU_ETNIA                     546212 non-null  object
#  10  ESTU_DEPTO_RESIDE              545835 non-null  object
#  11  ESTU_COD_RESIDE_DEPTO          546212 non-null  object
# ...

# %%
df.describe()
# Out:
#         PERIODO  COLE_CODIGO_ICFES  COLE_COD_DANE_ESTABLECIMIENTO  \
# count  546212.0      546212.000000                   5.462120e+05
# mean    20194.0      197397.840712                   2.038424e+11
# std         0.0      229636.502160                   9.221826e+10
# min     20194.0          75.000000                   1.050010e+11
# 25%     20194.0       45732.000000                   1.170500e+11
# 50%     20194.0      113076.000000                   1.732085e+11
# 75%     20194.0      194779.000000                   3.050010e+11
# max     20194.0      728303.000000                   8.548740e+11
#
#        COLE_COD_DANE_SEDE  COLE_COD_MCPIO_UBICACION  COLE_COD_DEPTO_UBICACION  \
# count        5.462120e+05             546212.000000             546212.000000
# mean         2.044208e+11              32755.704584                 32.516563
# std          9.302404e+10              26364.009436                 26.340054
# ...

# %%
df.dtypes.value_counts()
# Out:
# object     58
# int64      22
# float64     2
# dtype: int64

# %%
df.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO',
#        'ESTU_ESTUDIANTE', 'ESTU_TIENEETNIA', 'ESTU_PAIS_RESIDE', 'ESTU_ETNIA',
#        'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_MCPIO_RESIDE',
#        'ESTU_COD_RESIDE_MCPIO', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
#        'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE',
#        'FAMI_TRABAJOLABORPADRE', 'FAMI_TRABAJOLABORMADRE',
#        'FAMI_TIENEINTERNET', 'FAMI_TIENESERVICIOTV', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENELAVADORA', 'FAMI_TIENEHORNOMICROOGAS', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENEMOTOCICLETA', 'FAMI_TIENECONSOLAVIDEOJUEGOS',
#        'FAMI_NUMLIBROS', 'FAMI_COMELECHEDERIVADOS',
#        'FAMI_COMECARNEPESCADOHUEVO', 'FAMI_COMECEREALFRUTOSLEGUMBRE',
#        'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
#        'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA',
# ...

# %% [markdown]
# ## Null values

# %%
df.isnull().sum()
# Out:
# ESTU_TIPODOCUMENTO              0
# ESTU_NACIONALIDAD               0
# ESTU_GENERO                     0
# ESTU_FECHANACIMIENTO            0
# PERIODO                         0
#                             ...
# ESTU_INSE_INDIVIDUAL            4
# ESTU_NSE_INDIVIDUAL         17041
# ESTU_NSE_ESTABLECIMIENTO       44
# ESTU_ESTADOINVESTIGACION        0
# ESTU_GENERACION-E               0
# Length: 82, dtype: int64

# %% [markdown]
# Dealing with null values

# %%
type(df['ESTU_INSE_INDIVIDUAL'][0])
# Out:
# str

# %%
#df = df.fillna({'ESTU_INSE_INDIVIDUAL': '', 'ESTU_NSE_INDIVIDUAL': df['ESTU_NSE_INDIVIDUAL'].mean(), 'ESTU_NSE_ESTABLECIMIENTO': df['ESTU_NSE_ESTABLECIMIENTO'].mean() })

# %%
df.isnull().sum()
# Out:
# ESTU_TIPODOCUMENTO              0
# ESTU_NACIONALIDAD               0
# ESTU_GENERO                     0
# ESTU_FECHANACIMIENTO            0
# PERIODO                         0
#                             ...
# ESTU_INSE_INDIVIDUAL            4
# ESTU_NSE_INDIVIDUAL         17041
# ESTU_NSE_ESTABLECIMIENTO       44
# ESTU_ESTADOINVESTIGACION        0
# ESTU_GENERACION-E               0
# Length: 82, dtype: int64

# %% [markdown]
# ## Data Exploration
# ### Top 10 Schools with the best scores

# %%
df.groupby(['COLE_NOMBRE_ESTABLECIMIENTO'])['PUNT_GLOBAL'].mean()
# Out:
# COLE_NOMBRE_ESTABLECIMIENTO
# ACAD AMERICANA DE SISTEMAS Y COMERCIO    206.235294
# ACAD CENTRAL DE SISTEMAS ACSI            233.090909
# ACAD PANTANO DE VARGAS                   266.000000
# ACADEMIA ACADEMIA SAM                    244.250000
# ACADEMIA CIAL DE LOS ANDES               255.409639
#                                             ...
# UNION SINDICAL OBRERA  USO               206.600000
# UNITECNICAS                              223.410959
# WINDSOR ROYAL SCHOL                      295.125000
# ZARAGOZA                                 244.962264
# ZION SCHOOL                              306.166667
# Name: PUNT_GLOBAL, Length: 9372, dtype: float64

# %%
len((df['COLE_NOMBRE_ESTABLECIMIENTO'].unique()))
# Out:
# 9372

# %%
puntajes = df.groupby(['COLE_NOMBRE_ESTABLECIMIENTO'])['PUNT_GLOBAL'].mean()
puntajes = puntajes.sort_values(ascending=False)
print(puntajes)
colegios = puntajes.index.tolist()
puntajes = puntajes.tolist()

top_10_colegios = []
top_10_puntajes = []

for i in range(10):
    top_10_colegios.append(colegios[i])
    top_10_puntajes.append(puntajes[i])

#Reversing list for better data visualization
top_10_colegios.reverse()
top_10_puntajes.reverse()


#Ploting
plt.barh(top_10_colegios, top_10_puntajes)
plt.title('Colegios con mejores puntajes del ICFES 2019')
plt.xlabel('Puntajes')
plt.show()
# Out:
# COLE_NOMBRE_ESTABLECIMIENTO
# CENTRO EDUCATIVO ANTARES             395.000000
# LIC CAMPO DAVID                      388.800000
# INST ALBERTO MERANI                  375.321429
# COL NUEVO COLOMBO AMERICANO          372.178571
# COL ANGLO AMERICANO                  371.768362
#                                         ...
# IE INDÍGENA DE MONDO                 144.000000
# IE INDÍGENA EUCICIO ISARAMA          143.727273
# IE INDÍGENA TOBIAS QUERAGAMA         141.200000
# IE INDÍGENA MARIO CHAMORRO           140.818182
# CE INDÍGENA JUAN ANTONIO CHAMORRO    138.444444
# Name: PUNT_GLOBAL, Length: 9372, dtype: float64

# %% [markdown]
# A qué regiones pertenecen esos colegios:

# %%
#df.columns
df_filtered = df.query('COLE_NOMBRE_ESTABLECIMIENTO == "CENTRO EDUCATIVO ANTARES"')
print(df_filtered[['COLE_NOMBRE_ESTABLECIMIENTO','ESTU_DEPTO_RESIDE']].head(1))
df_filtered = df.query('COLE_NOMBRE_ESTABLECIMIENTO == "LIC CAMPO DAVID"')
print(df_filtered[['COLE_NOMBRE_ESTABLECIMIENTO','ESTU_DEPTO_RESIDE']].head(1))
df_filtered = df.query('COLE_NOMBRE_ESTABLECIMIENTO == "INST ALBERTO MERANI"')
print(df_filtered[['COLE_NOMBRE_ESTABLECIMIENTO','ESTU_DEPTO_RESIDE']].head(1))
df_filtered = df.query('COLE_NOMBRE_ESTABLECIMIENTO == "COL NUEVO COLOMBO AMERICANO"')
print(df_filtered[['COLE_NOMBRE_ESTABLECIMIENTO','ESTU_DEPTO_RESIDE']].head(1))
df_filtered = df.query('COLE_NOMBRE_ESTABLECIMIENTO == "COL ANGLOAMERICANO"')
print(df_filtered[['COLE_NOMBRE_ESTABLECIMIENTO','ESTU_DEPTO_RESIDE']].head(1))
df_filtered = df.query('COLE_NOMBRE_ESTABLECIMIENTO == "CAMBRIDGE SCHOOL (GIMN BILING PLAZA SESAMO)"')
print(df_filtered[['COLE_NOMBRE_ESTABLECIMIENTO','ESTU_DEPTO_RESIDE']].head(1))
df_filtered = df.query('COLE_NOMBRE_ESTABLECIMIENTO == "LIC NAVARRA"')
print(df_filtered[['COLE_NOMBRE_ESTABLECIMIENTO','ESTU_DEPTO_RESIDE']].head(1))
df_filtered = df.query('COLE_NOMBRE_ESTABLECIMIENTO == "GIMNASIO COLOMBO BRITÁNICO - BILINGÜE INTERNACIONAL"')
print(df_filtered[['COLE_NOMBRE_ESTABLECIMIENTO','ESTU_DEPTO_RESIDE']].head(1))
df_filtered = df.query('COLE_NOMBRE_ESTABLECIMIENTO == "COL BILINGUE DIVINO NIÑO"')
print(df_filtered[['COLE_NOMBRE_ESTABLECIMIENTO','ESTU_DEPTO_RESIDE']].head(1))
df_filtered = df.query('COLE_NOMBRE_ESTABLECIMIENTO == "COLEGIO LOS ANGELES"')
print(df_filtered[['COLE_NOMBRE_ESTABLECIMIENTO','ESTU_DEPTO_RESIDE']].head(1))
# Out:
#       COLE_NOMBRE_ESTABLECIMIENTO ESTU_DEPTO_RESIDE
# 17436    CENTRO EDUCATIVO ANTARES            CALDAS
#       COLE_NOMBRE_ESTABLECIMIENTO ESTU_DEPTO_RESIDE
# 31869             LIC CAMPO DAVID            BOGOTÁ
#      COLE_NOMBRE_ESTABLECIMIENTO ESTU_DEPTO_RESIDE
# 7889         INST ALBERTO MERANI            BOGOTÁ
#        COLE_NOMBRE_ESTABLECIMIENTO ESTU_DEPTO_RESIDE
# 11079  COL NUEVO COLOMBO AMERICANO            BOGOTÁ
#      COLE_NOMBRE_ESTABLECIMIENTO ESTU_DEPTO_RESIDE
# 7645          COL ANGLOAMERICANO         RISARALDA
#                       COLE_NOMBRE_ESTABLECIMIENTO ESTU_DEPTO_RESIDE
# 2178  CAMBRIDGE SCHOOL (GIMN BILING PLAZA SESAMO)   NORTE SANTANDER
#       COLE_NOMBRE_ESTABLECIMIENTO ESTU_DEPTO_RESIDE
# 25905                 LIC NAVARRA            BOGOTÁ
# Empty DataFrame
# Columns: [COLE_NOMBRE_ESTABLECIMIENTO, ESTU_DEPTO_RESIDE]
# Index: []
#       COLE_NOMBRE_ESTABLECIMIENTO ESTU_DEPTO_RESIDE
# 25233    COL BILINGUE DIVINO NIÑO         SANTANDER
# ...
