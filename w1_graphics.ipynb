# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ### The exercise
#
# | Complexity function | O - Notation |
# | --- | --- |
# | 1000*n | O(n) |
# | 200(n log n) | O(n log n) |
# | 10*n^{2} | O(n^2) |
# | 2^{n} | O(2^n) |

# %% [markdown]
# Functions

# %%
def lineal(x):
    y = 1000 *x
    return y

def logarithmic(x):
    y = 200*x*np.log(x)
    return y

def cuadratica(x):
    y = 10 *(x**2)
    return y

def exponencial(x):
    y = 2**x
    return y

# %% [markdown]
# Plotting

# %%
x = np.linspace (1, 15,100) 
plt.plot(x,lineal(x), label='Linear')
plt.plot(x,logarithmic(x), label='n log n')
plt.plot(x,cuadratica(x), label='Quadratic')
plt.plot(x,exponencial(x), label='Exponential')
plt.title('Orders of complexity')
plt.xlabel('n')
plt.ylabel('T(n)')
plt.legend()
plt.show()

# %% [markdown]
# ### Second Part - Ranking
#
# | Complexity function | O - Notation | Rank |
# | --- | --- | --- |
# | n! | O(n!) | 1 |
# | e^n | O(2^n) | 2 |
# | 2^n | O(2^n) | 3 |
# | (3/2)^n | O(2^n) | 4 |
# | n + n^7 + n^3 | O(n^7) | 5 |
# | n^2 log n | O(n^2) | 6 |
# | n^2 + log n| O(n^2) | 7 |
# | (n^2)/2 | O(n^2) | 8 |
# | sqrt(n) | O(n^(1/2)) | 9 |
# | n log n | O(n log n) | 10 |
